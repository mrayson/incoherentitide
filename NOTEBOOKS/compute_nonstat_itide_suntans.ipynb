# %% [markdown]
# # Calculate the nonstationary internal tide component
#
# # Dask worker setup instructions
#
# https://github.com/mrayson/pawsey-containers/tree/master/hpc-python/jupyter-sfoda
#
# These settings do the job:
#
#  1. `dask-scheduler --scheduler-file scheduler-$HOSTNAME.json --idle-timeout 0`
#  2. `ssh localhost "cd /software/projects/pawsey0106/mrayson/projects && sbatch --ntasks=16 -c 16 start_worker.slm scheduler-$HOSTNAME.json ./"`

# %%
# !echo $(hostname)
# Out:
# nid002537

# %%
import os
from distributed import Client
client=Client(scheduler_file='../../scheduler-' + 'nid002537' + '.json')
client
# Out:
# <Client: 'tcp://10.253.136.193:8786' processes=64 threads=1024, memory=1.68 TiB>

# %%
client.restart() # This clears all data
# Out:
# <Client: 'tcp://10.253.136.193:8786' processes=33 threads=528, memory=886.70 GiB>

# %%
import sfoda.suntans.sunxarray as sxr

import glob
import xarray as xr
import numpy as np
import matplotlib.pyplot as plt
from cmocean import cm
from s3fs import S3FileSystem, S3Map
# Out:
# Matplotlib created a temporary config/cache directory at /tmp/matplotlib-vb0jlr9z because the default path (/home/jovyan/.cache/matplotlib) is not a writable directory; it is highly recommended to set the MPLCONFIGDIR environment variable to a writable directory, in particular to speed up the import of Matplotlib and to better support multiprocessing.

# %%
s3login = '/home/mrayson/code/s3.acacia.login'

with open(s3login) as f:
    lines = f.readlines()

url, key, secret = [ff.strip('\n') for ff in lines[0:3]]
s3 = S3FileSystem(client_kwargs={'endpoint_url':url},
            key=key,
            secret=secret)

# %%
f = S3Map("uwaoceanprocesses-suntans/NWS_2km_GLORYS_2013_2014_ssh_steric.zarr/", s3=s3)
varname = 'eta_steric'

# f = S3Map("uwaoceanprocesses-suntans/NWS_2km_GLORYS_2013_2014_surface.zarr/", s3=s3)
# varname = 'eta'


# cutoff_dt = 40*3600
# cutoff_dt_high = 6*3600
# dtsec = 3600.

# zarrfile = 'NWS_2km_GLORYS_2013_2014_ssh_steric_filtered.zarr'

cutoff_dt = 40*3600
cutoff_dt_high = 4*3600
dtsec = 3600.

zarrfile = 'NWS_2km_GLORYS_2013_2014_ssh_steric_filtered_v2.zarr'

# %%
ds = xr.open_dataset(f, engine='zarr', chunks={})

# These need filling in??
ds.suntans.xv=ds.xv.values
ds.suntans.yv=ds.yv.values

ds
# Out:
# Changing the _FillValue from -999999 to 999999
# <xarray.Dataset>
# Dimensions:     (Nc: 225368, numsides: 8, time: 8772, Np: 454016)
# Coordinates:
#   * time        (time) datetime64[ns] 2013-07-01T00:01:00 ... 2014-07-01
# Dimensions without coordinates: Nc, numsides, Np
# Data variables:
#     cells       (Nc, numsides) int32 dask.array<chunksize=(2000, 8), meta=np.ndarray>
#     dv          (Nc) float64 dask.array<chunksize=(2000,), meta=np.ndarray>
#     eta_steric  (time, Nc) float64 dask.array<chunksize=(745, 2000), meta=np.ndarray>
#     nfaces      (Nc) int32 dask.array<chunksize=(2000,), meta=np.ndarray>
#     xp          (Np) float64 dask.array<chunksize=(454016,), meta=np.ndarray>
#     xv          (Nc) float64 dask.array<chunksize=(2000,), meta=np.ndarray>
#     yp          (Np) float64 dask.array<chunksize=(454016,), meta=np.ndarray>
#     yv          (Nc) float64 dask.array<chunksize=(2000,), meta=np.ndarray>
# Attributes:
#     Author:       mrayson
#     Description:  SUNTANS post-processed pressure fields

# %%
# Need to fix the time because the restart at each month lead to non-continuous time stepping
# Find and remove duplicate time entries
tsec = (ds.time.values-ds.time.values[0]).astype(float)/1e9
dt = np.ones(tsec.shape)

dt[1:] = tsec[1:]-tsec[0:-1]
dt[0] = dt[1]*1

#plt.plot(dt)

#badidx = dt<dt.max()
#dt[np.argwhere(badidx)]

remove_idx = dt==60.
# fix_idx = dt==3540.

# myds.time.isel(time=fix_idx) + np.timedelta64(60,'s')
ds2 = ds.isel(time=~remove_idx).chunk({'time':-1})
# Out:
# /opt/conda/lib/python3.10/site-packages/xarray/core/indexing.py:1374: PerformanceWarning: Slicing is producing a large chunk. To accept the large
# chunk and silence this warning, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': False}):
#     ...     array[indexer]
#
# To avoid creating the large chunks, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': True}):
#     ...     array[indexer]
#   return self.array[key]

# %%
ds2[varname]
# Out:
# <xarray.DataArray 'eta_steric' (time: 8761, Nc: 225368)>
# dask.array<rechunk-merge, shape=(8761, 225368), dtype=float64, chunksize=(8761, 2000), chunktype=numpy.ndarray>
# Coordinates:
#   * time     (time) datetime64[ns] 2013-07-01T00:01:00 ... 2014-07-01
# Dimensions without coordinates: Nc
# Attributes:
#     location:   face
#     long_name:  steric sea surface height
#     units:      m

# %% [raw]
# # Test dask computations
# eta_std = ds2[varname].std(axis=0)
# eta_std

# %% [raw]
# eta_std.compute()

# %%
from scipy import signal


def filt(ytmp, cutoff_dt, dt, btype='low', order=8, ftype='sos', axis=-1):
    """
    Butterworth filter the time series

    Inputs:
        cutoff_dt - cuttoff period [seconds]
        btype - 'low' or 'high' or 'band'
    """
    if not btype == 'band':
        Wn = dt/cutoff_dt
    else:
        Wn = [dt/co for co in cutoff_dt]
    
    if ftype=='sos':
        sos = signal.butter(order, Wn, btype, analog=False, output='sos')
        return signal.sosfiltfilt(sos, ytmp, axis=axis)
    else:
        (b, a) = signal.butter(order, Wn, btype=btype, analog=0, output='ba')
        return signal.filtfilt(b, a, ytmp, axis=axis)

def testfunc(arr, axis=0):
    return arr*2

# %%
# %%time
#from functools import partial
arr = ds2[varname]

# Compute the filted variable
# arr_filt = xr.apply_ufunc(testfunc,
#                           arr, 
#                           dask='parallelized',
#                           output_dtypes=[arr.dtype],
#                           input_core_dims=([],),
#                           #output_core_dims=(['time','Nc']),
#                           kwargs={'axis': 0},
#                          )

# # Compute the filted variable
arr_lowpass = xr.apply_ufunc(filt,
                          arr, 
                          cutoff_dt,
                          dtsec,
                          dask='parallelized',
                          output_dtypes=[arr.dtype],
                          #input_core_dims=(['time','Nc'], [], []),
                          #output_core_dims=(['time','Nc']),
                          kwargs={'axis': 0},
                          #dask_gufunc_kwargs={'allow_rechunk':True}
                         )


arr_lowpass
# Out:
# CPU times: user 4.37 ms, sys: 46 µs, total: 4.42 ms
# Wall time: 4.43 ms
# <xarray.DataArray 'eta_steric' (time: 8761, Nc: 225368)>
# dask.array<transpose, shape=(8761, 225368), dtype=float64, chunksize=(8761, 2000), chunktype=numpy.ndarray>
# Coordinates:
#   * time     (time) datetime64[ns] 2013-07-01T00:01:00 ... 2014-07-01
# Dimensions without coordinates: Nc

# %%
arr_highpass = xr.apply_ufunc(filt,
                          ds2[varname], 
                          #[cutoff_dt, cutoff_dt_high],
                          cutoff_dt_high,
                          dtsec,
                          dask='parallelized',
                          output_dtypes=[arr.dtype],
                          #input_core_dims=(['time','Nc'], [], []),
                          #output_core_dims=(['time','Nc']),
                          kwargs={'axis': 0, 'btype':'high'},
                          #dask_gufunc_kwargs={'allow_rechunk':True}
                         )

arr_highpass
# Out:
# <xarray.DataArray 'eta_steric' (time: 8761, Nc: 225368)>
# dask.array<transpose, shape=(8761, 225368), dtype=float64, chunksize=(8761, 2000), chunktype=numpy.ndarray>
# Coordinates:
#   * time     (time) datetime64[ns] 2013-07-01T00:01:00 ... 2014-07-01
# Dimensions without coordinates: Nc

# %%
arr_bandpass = arr - arr_lowpass - arr_highpass

# %% [raw]
# # Create an output data set
# dsout = ds2.drop_vars(['uc','vc','temp'])
#
# dsout['eta_lowpass'] = xr.DataArray(arr_lowpass, dims=('time','Nc'),
#                                            attrs=
#                                 {'long_name':'sea surface height','units':'m','location':'face',
#                                 'filter_cutoff_sec':cutoff_dt} )
#
# dsout['eta_bandpass'] = xr.DataArray(arr_bandpass, dims=('time','Nc'),
#                                            attrs=
#                                 {'long_name':'sea surface height','units':'m','location':'face',
#                                 'filter_cutoff_sec':cutoff_dt_high} )
# dsout

# %%
# Create an output data set
dsout = ds2.drop_vars(['eta_steric'])

dsout['eta_steric_lowpass'] = xr.DataArray(arr_lowpass, dims=('time','Nc'), 
                                           attrs=
                                {'long_name':'steric sea surface height','units':'m','location':'face',
                                'filter_cutoff_sec':cutoff_dt} )

dsout['eta_steric_bandpass'] = xr.DataArray(arr_bandpass, dims=('time','Nc'), 
                                           attrs=
                                {'long_name':'steric sea surface height','units':'m','location':'face',
                                'filter_cutoff_sec':cutoff_dt_high} )
dsout
# Out:
# <xarray.Dataset>
# Dimensions:              (Nc: 225368, numsides: 8, time: 8761, Np: 454016)
# Coordinates:
#   * time                 (time) datetime64[ns] 2013-07-01T00:01:00 ... 2014-0...
# Dimensions without coordinates: Nc, numsides, Np
# Data variables:
#     cells                (Nc, numsides) int32 dask.array<chunksize=(2000, 8), meta=np.ndarray>
#     dv                   (Nc) float64 dask.array<chunksize=(2000,), meta=np.ndarray>
#     nfaces               (Nc) int32 dask.array<chunksize=(2000,), meta=np.ndarray>
#     xp                   (Np) float64 dask.array<chunksize=(454016,), meta=np.ndarray>
#     xv                   (Nc) float64 dask.array<chunksize=(2000,), meta=np.ndarray>
#     yp                   (Np) float64 dask.array<chunksize=(454016,), meta=np.ndarray>
#     yv                   (Nc) float64 dask.array<chunksize=(2000,), meta=np.ndarray>
#     eta_steric_lowpass   (time, Nc) float64 dask.array<chunksize=(8761, 2000), meta=np.ndarray>
#     eta_steric_bandpass  (time, Nc) float64 dask.array<chunksize=(8761, 2000), meta=np.ndarray>
# Attributes:
#     Author:       mrayson
#     Description:  SUNTANS post-processed pressure fields

# %%
outfile = '/scratch/pawsey0106/mrayson/SUNTANS_NWS_2km/'+zarrfile

dsout.to_zarr(outfile, mode='w', append_dim=None, compute=True)
outfile
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [20], in <cell line: 3>()
#       1 outfile = '/scratch/pawsey0106/mrayson/SUNTANS_NWS_2km/'+zarrfile[:-5]+'.nc'
# ----> 3 dsout.to_zarr(outfile, mode='w', append_dim=None, compute=True)
#       4 outfile
#
# File /opt/conda/lib/python3.10/site-packages/xarray/core/dataset.py:2060, in Dataset.to_zarr(self, store, chunk_store, mode, synchronizer, group, encoding, compute, consolidated, append_dim, region, safe_chunks, storage_options)
#    1950 """Write dataset contents to a zarr group.
#    1951
#    1952 Zarr chunks are determined in the following way:
#    (...)
#    2056     The I/O user guide, with more details and examples.
#    2057 """
#    2058 from ..backends.api import to_zarr
# -> 2060 return to_zarr(  # type: ignore
#    2061     self,
#    2062     store=store,
#    2063     chunk_store=chunk_store,
#    2064     storage_options=storage_options,
#    2065     mode=mode,
#    2066     synchronizer=synchronizer,
#    2067     group=group,
#    2068     encoding=encoding,
#    2069     compute=compute,
#    2070     consolidated=consolidated,
#    2071     append_dim=append_dim,
#    2072     region=region,
#    2073     safe_chunks=safe_chunks,
#    2074 )
#
# File /opt/conda/lib/python3.10/site-packages/xarray/backends/api.py:1638, in to_zarr(dataset, store, chunk_store, mode, synchronizer, group, encoding, compute, consolidated, append_dim, region, safe_chunks, storage_options)
#    1636 # TODO: figure out how to properly handle unlimited_dims
#    1637 dump_to_store(dataset, zstore, writer, encoding=encoding)
# -> 1638 writes = writer.sync(compute=compute)
#    1640 if compute:
#    1641     _finalize_store(writes, zstore)
#
# File /opt/conda/lib/python3.10/site-packages/xarray/backends/common.py:168, in ArrayWriter.sync(self, compute)
#     162 import dask.array as da
#     164 # TODO: consider wrapping targets with dask.delayed, if this makes
#     165 # for any discernible difference in perforance, e.g.,
#     166 # targets = [dask.delayed(t) for t in self.targets]
# --> 168 delayed_store = da.store(
#     169     self.sources,
#     170     self.targets,
#     171     lock=self.lock,
#     172     compute=compute,
#     173     flush=True,
#     174     regions=self.regions,
#     175 )
#     176 self.sources = []
#     177 self.targets = []
#
# File /opt/conda/lib/python3.10/site-packages/dask/array/core.py:1223, in store(***failed resolving arguments***)
#    1221 elif compute:
#    1222     store_dsk = HighLevelGraph(layers, dependencies)
# -> 1223     compute_as_if_collection(Array, store_dsk, map_keys, **kwargs)
#    1224     return None
#    1226 else:
#
# File /opt/conda/lib/python3.10/site-packages/dask/base.py:344, in compute_as_if_collection(cls, dsk, keys, scheduler, get, **kwargs)
#     341 # see https://github.com/dask/dask/issues/8991.
#     342 # This merge should be removed once the underlying issue is fixed.
#     343 dsk2 = HighLevelGraph.merge(dsk2)
# --> 344 return schedule(dsk2, keys, **kwargs)
#
# File /opt/conda/lib/python3.10/site-packages/dask/threaded.py:81, in get(dsk, result, cache, num_workers, pool, **kwargs)
#      78     elif isinstance(pool, multiprocessing.pool.Pool):
#      79         pool = MultiprocessingPoolExecutor(pool)
# ---> 81 results = get_async(
#      82     pool.submit,
#      83     pool._max_workers,
#      84     dsk,
#      85     result,
#      86     cache=cache,
#      87     get_id=_thread_get_id,
#      88     pack_exception=pack_exception,
#      89     **kwargs,
#      90 )
#      92 # Cleanup pools associated to dead threads
#      93 with pools_lock:
#
# File /opt/conda/lib/python3.10/site-packages/dask/local.py:497, in get_async(submit, num_workers, dsk, result, cache, get_id, rerun_exceptions_locally, pack_exception, raise_exception, callbacks, dumps, loads, chunksize, **kwargs)
#     495 while state["waiting"] or state["ready"] or state["running"]:
#     496     fire_tasks(chunksize)
# --> 497     for key, res_info, failed in queue_get(queue).result():
#     498         if failed:
#     499             exc, tb = loads(res_info)
#
# File /opt/conda/lib/python3.10/site-packages/dask/local.py:134, in queue_get(q)
#     133 def queue_get(q):
# --> 134     return q.get()
#
# File /opt/conda/lib/python3.10/queue.py:171, in Queue.get(self, block, timeout)
#     169 elif timeout is None:
#     170     while not self._qsize():
# --> 171         self.not_empty.wait()
#     172 elif timeout < 0:
#     173     raise ValueError("'timeout' must be a non-negative number")
#
# File /opt/conda/lib/python3.10/threading.py:320, in Condition.wait(self, timeout)
#     318 try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     319     if timeout is None:
# --> 320         waiter.acquire()
#     321         gotit = True
#     322     else:
#
# KeyboardInterrupt:

# %%
# Save time chunked output
d = S3Map("uwaoceanprocesses-suntans/"+zarrfile, s3=s3)

dsout.to_zarr(store=d, mode='w', compute=True, safe_chunks=False)

# %%
zarrfile
# Out:
# 'NWS_2km_GLORYS_2013_2014_ssh_steric_filtered_v2.zarr'

# %%
# Save time chunked output
d = S3Map("uwaoceanprocesses-suntans/"+zarrfile, s3=s3)

dsout.to_zarr(store=d, mode='w', compute=True, safe_chunks=False)
